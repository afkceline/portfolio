# %% [markdown]
# # Entregable 3

# %%
import numpy as np
import pandas as pd
import io

from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# ## 🎈 1. Ejercicio: Arkansas 🎈

# %% [markdown]
# Queremos obtener de la página de Wikipedia de "Arkansas", https://es.wikipedia.org/wiki/Arkansas, la tabla que nos indica la composición étnica a aprtir del censo de EEUU de 2020.
#
# - Revisar la página web de Wikipedia y obtener la tabla en un df
# - Sobre el df: revisar qué tipo de columnas tenemos y que valores contienen las mismas
# - Renombrar las columnas a nombres más descriptivos
# - Eliminar columnas que no sean necesarias
# - Cambiar a tipo numérico (realizando los cambios necesarios, %) las columnas que contienen números
# - **Realizar un análisis exploratorio sobre la tabla**

# %%
url = 'https://es.wikipedia.org/wiki/Arkansas'

# %%
# URL de Wikipedia
url = 'https://es.wikipedia.org/wiki/Arkansas'

# Simulamos un navegador para evitar el error 403
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/123.0 Safari/537.36'
}

# Realizar la solicitud GET con el User-Agent especificado
response = requests.get(url, headers=headers)

# %%
print(f"response: {response}")
print(f"response.status_code: {response.status_code}")
# Out:
# response: <Response [200]>
# response.status_code: 200

# %%
type(response.text)
# Out:
# str

# %%
# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Utilizar pandas.read_html para extraer la tabla de la respuesta HTML
    tables = pd.read_html(response.text)
    print(f"El número de tablas encontradas: {len(tables)} \n\n")
else:
    print(f"Error: {response.status_code}")
# Out:
# El número de tablas encontradas: 7
# /tmp/ipykernel_2266/2768303041.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)

# %%
io.StringIO(response.text)

# %%
# URL de Wikipedia
url = 'https://es.wikipedia.org/wiki/Arkansas'

# Simulamos un navegador para evitar el error 403
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/123.0 Safari/537.36'
}

# Realizar la solicitud GET con el User-Agent especificado
response = requests.get(url, headers=headers)

if response.status_code == 200:
    # Convertir el HTML en un archivo de html
    html_content = io.StringIO(response.text)

    # Extraer tablas sin warning
    tables = pd.read_html(html_content)

    print(f"El número de tablas encontradas: {len(tables)} \n")
else:
    print(f"Error: {response.status_code}")
# Out:
# El número de tablas encontradas: 7

# %%
type(tables)
# Out:
# list

# %%
# Mostramos la primera tabla
display(tables[0].head())
# Out:
#                           Arkansas State of Arkansas  \
# 0                                    Estado federado
# 1                                     Bandera Escudo
# 2                                            Bandera
# 3  Otros nombres: The Natural State, Land of Oppo...
# 4  Lema: En latín: Regnat populus  (En español: E...
#
#                         Arkansas State of Arkansas.1  \
# 0                                    Estado federado
# 1                                     Bandera Escudo
# 2                                             Escudo
# 3  Otros nombres: The Natural State, Land of Oppo...
# 4  Lema: En latín: Regnat populus  (En español: E...
#
#                         Arkansas State of Arkansas.2
# 0                                    Estado federado
# 1                                     Bandera Escudo
# 2                                                NaN
# 3  Otros nombres: The Natural State, Land of Oppo...
# 4  Lema: En latín: Regnat populus  (En español: E...

# %%
#Se hace la búsqueda de la tabla de forma manual

display(tables[4].head())
# Out:
#           Raza y etnia[10]  Alone  Alone.1  Total  Total.1
# 0        Blanco no hispano  68.5%      NaN  73.2%      NaN
# 1                   Negros  14.9%      NaN  16.2%      NaN
# 2  Hispanios o Latinos[11]      —      NaN   8.5%      NaN
# 3                Asiáticos   1.7%      NaN   2.2%      NaN
# 4                  Nativos   0.7%      NaN   3.4%      NaN

# %%
#Convertimos a dataframe para poder trabajar con los datos

df = tables[4]
df
# Out:
#                             Raza y etnia[10]  Alone  Alone.1  Total  Total.1
# 0                          Blanco no hispano  68.5%      NaN  73.2%      NaN
# 1                                     Negros  14.9%      NaN  16.2%      NaN
# 2                    Hispanios o Latinos[11]      —      NaN   8.5%      NaN
# 3                                  Asiáticos   1.7%      NaN   2.2%      NaN
# 4                                    Nativos   0.7%      NaN   3.4%      NaN
# 5  Estadounidenses de las islas del Pacífico   0.5%      NaN   0.6%      NaN
# 6                                       Otro   0.3%      NaN   1.1%      NaN

# %%
#Comprobamos el tipo de datos que tenemos en el df

df.dtypes
# Out:
# Raza y etnia[10]     object
# Alone                object
# Alone.1             float64
# Total                object
# Total.1             float64
# dtype: object

# %%
#Eliminamos las columnas sin información

df_1 = df.drop(columns=['Alone.1', 'Total.1'])
df_1
# Out:
#                             Raza y etnia[10]  Alone  Total
# 0                          Blanco no hispano  68.5%  73.2%
# 1                                     Negros  14.9%  16.2%
# 2                    Hispanios o Latinos[11]      —   8.5%
# 3                                  Asiáticos   1.7%   2.2%
# 4                                    Nativos   0.7%   3.4%
# 5  Estadounidenses de las islas del Pacífico   0.5%   0.6%
# 6                                       Otro   0.3%   1.1%

# %%
#Renombramos las columnas para que sean más claras

df_1 = df_1.rename(columns={
    'Raza y etnia[11]​': 'etnia',
    'Alone': 'porcentaje'
})

# %%
df_1
# Out:
#                             Raza y etnia[10] porcentaje  Total
# 0                          Blanco no hispano      68.5%  73.2%
# 1                                     Negros      14.9%  16.2%
# 2                    Hispanios o Latinos[11]          —   8.5%
# 3                                  Asiáticos       1.7%   2.2%
# 4                                    Nativos       0.7%   3.4%
# 5  Estadounidenses de las islas del Pacífico       0.5%   0.6%
# 6                                       Otro       0.3%   1.1%

# %%
#Realizamos un análisis exploratorio

df_1.describe()
# Out:
#          Raza y etnia[10] porcentaje  Total
# count                   7          7      7
# unique                  7          7      7
# top     Blanco no hispano      68.5%  73.2%
# freq                    1          1      1

# %%
#Como el anterior código nos ha arrojado resultados inesperados, volvemos a comprobar los datos

df_1.dtypes
# Out:
# Raza y etnia[10]    object
# porcentaje          object
# Total               object
# dtype: object

# %%
#Transformamos a float

df_1['porcentaje'] = (
    df_1['porcentaje']
    .str.replace('%','', regex=False)
    .str.replace(',','.', regex=False)
    .str.replace('—','', regex=False)
    .str.strip()
    .replace('', None)
    .astype(float)
)

df_1['Total'] = (
    df_1['Total']
    .str.replace('%','', regex=False)
    .str.replace(',','.', regex=False)
    .str.replace('—','', regex=False)
    .str.strip()
    .replace('', None)
    .astype(float)
)

# %%
df_1.dtypes
# Out:
# Raza y etnia[10]     object
# porcentaje          float64
# Total               float64
# dtype: object

# %%
df_1[['porcentaje','Total']].describe()
# Out:
#        porcentaje      Total
# count    6.000000   7.000000
# mean    14.433333  15.028571
# std     27.085248  26.235772
# min      0.300000   0.600000
# 25%      0.550000   1.650000
# 50%      1.200000   3.400000
# 75%     11.600000  12.350000
# max     68.500000  73.200000

# %% [markdown]
# La tabla inicial recogida de Wikipedia ya nos da los datos ordenados que nos muestran que la etnia dominante es la 'Blanco no hispano', con un 73%, seguida de los 'Negros' con un 16%.

# %% [markdown]
# ## 🎈 2. Ejercicio pandas 🎈

# %% [markdown]
# - Pandas: scrapear la tabla que contiene informacion sobre los álbums más vendidos por año en todo el mundo (https://es.wikipedia.org/wiki/Anexo:%C3%81lbumes_musicales_m%C3%A1s_vendidos) generando un dataframe con la información del año, nombre del álbum, artista y ventas. Ésta ultima columna deberá tener sus valores en numeros enteros en millones.

# %%
url = 'https://es.wikipedia.org/wiki/Anexo:%C3%81lbumes_musicales_m%C3%A1s_vendidos)'

# %%
# URL de Wikipedia
url = 'https://es.wikipedia.org/wiki/Anexo:%C3%81lbumes_musicales_m%C3%A1s_vendidos)'
# Simulamos un navegador para evitar el error 403
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/123.0 Safari/537.36'
}

# Realizar la solicitud GET con el User-Agent especificado
response = requests.get(url, headers=headers)

# %%
print(f"response: {response}")
print(f"response.status_code: {response.status_code}")
# Out:
# response: <Response [404]>
# response.status_code: 404

# %% [markdown]
# Como nos da el código 404, vamos a probar a cambiar la url por la actual

# %%
# URL de Wikipedia
url = 'https://es.wikipedia.org/wiki/Anexo:%C3%81lbumes_musicales_m%C3%A1s_vendidos#%C3%81lbum_m%C3%A1s_vendido_por_a%C3%B1o_en_todo_el_mundo'

# Simulamos un navegador para evitar el error 403
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/123.0 Safari/537.36'
}

# Realizar la solicitud GET con el User-Agent especificado
response = requests.get(url, headers=headers)

# %%
print(f"response: {response}")
print(f"response.status_code: {response.status_code}")
# Out:
# response: <Response [200]>
# response.status_code: 200

# %%
type(response.text)
# Out:
# str

# %%
# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    # Utilizar pandas.read_html para extraer la tabla de la respuesta HTML
    tables = pd.read_html(response.text)
    print(f"El número de tablas encontradas: {len(tables)} \n\n")
else:
    print(f"Error: {response.status_code}")
# Out:
# El número de tablas encontradas: 7
# /tmp/ipykernel_2266/2768303041.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)

# %%
io.StringIO(response.text)

# %%
# URL de Wikipedia
url = 'https://es.wikipedia.org/wiki/Anexo:%C3%81lbumes_musicales_m%C3%A1s_vendidos#%C3%81lbum_m%C3%A1s_vendido_por_a%C3%B1o_en_todo_el_mundo'

# Simulamos un navegador para evitar el error 403
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/123.0 Safari/537.36'
}

# Realizar la solicitud GET con el User-Agent especificado
response = requests.get(url, headers=headers)

if response.status_code == 200:
    # Convertir el HTML en un archivo de html
    html_content = io.StringIO(response.text)

    # Extraer tablas sin warning
    tables = pd.read_html(html_content)

    print(f"El número de tablas encontradas: {len(tables)} \n")
else:
    print(f"Error: {response.status_code}")
# Out:
# El número de tablas encontradas: 7

# %%
type(tables)
# Out:
# list

# %%
# Mostramos la primera tabla
display(tables[0].head())
# Out:
#                      0
# 0     Álbum de estudio
# 1  Álbum recopilatorio
# 2         Banda sonora
# 3        Álbum en vivo

# %%
#Buscamos la tabla que necesitamos

url = 'https://es.wikipedia.org/wiki/Anexo:%C3%81lbumes_musicales_m%C3%A1s_vendidos#%C3%81lbum_m%C3%A1s_vendido_por_a%C3%B1o_en_todo_el_mundo'

# Simulamos un navegador para evitar el error 403
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/123.0 Safari/537.36'
}

# Realizar la solicitud GET con el User-Agent especificado
response = requests.get(url, headers=headers)

if response.status_code == 200:
    # Convertir el HTML en un archivo de html
    html_content = io.StringIO(response.text)

    # Extraer tablas sin warning
    # # Filtramos las tablas que contienen el texto "Ref" en el encabezado
    tables = pd.read_html(html_content, match='Ref')

    print(f"El número de tablas encontradas: {len(tables)} \n")
else:
    print(f"Error: {response.status_code}")
# Out:
# El número de tablas encontradas: 1

# %%
#Esta es la tabla que coincide con lo pedido en el ejercicio

display(tables[0].head())
# Out:
#       Año              Álbum   Artista(s)  Ventas (millones) Ref(s)
# 0  2001.0      Hybrid Theory  Linkin Park                9.0  [191]
# 1  2002.0    The Eminem Show       Eminem               13.9  [192]
# 2  2003.0  Come Away with Me  Norah Jones               11.0  [193]
# 3  2004.0        Confessions        Usher               12.0  [194]
# 4  2005.0                X&Y     Coldplay                8.3  [195]

# %%
#Convertimos a dataframe para poder trabajar con los datos

df_a = tables[0]
df_a
# Out:
#        Año                                      Álbum  \
# 0   2001.0                              Hybrid Theory
# 1   2002.0                            The Eminem Show
# 2   2003.0                          Come Away with Me
# 3   2004.0                                Confessions
# 4   2005.0                                        X&Y
# 5   2006.0                        High School Musical
# 6   2007.0                      High School Musical 2
# 7   2008.0  Viva la Vida or Death and All His Friends
# 8   2009.0                          I Dreamed a Dream
# 9   2010.0                                   Recovery
# 10  2011.0                                         21
# 11  2012.0                                         21
# 12  2013.0                          Midnight Memories
# 13  2014.0                                     Frozen
# 14  2015.0                                         25
# 15  2016.0                                   Lemonade
# 16  2017.0                                          ÷
# 17  2018.0                       The Greatest Showman
# 18  2019.0              5x20 All the Best!! 1999–2019
# 19  2020.0                         Map of the Soul: 7
# 20  2021.0                                         30
# 21  2022.0                      Greatest Works of Art
# 22  2023.0                                        FML
# 23  2024.0              The Tortured Poets Department
# 24  2025.0                     The Life of a Showgirl
# 25     NaN                                        NaN
#
#                         Artista(s)  Ventas (millones)      Ref(s)
# 0                      Linkin Park               9.00       [191]
# 1                           Eminem              13.90       [192]
# 2                      Norah Jones              11.00       [193]
# 3                            Usher              12.00       [194]
# 4                         Coldplay               8.30       [195]
# 5                  Artistas varios               7.00       [196]
# 6                  Artistas varios               6.00       [197]
# 7                         Coldplay               6.80       [198]
# 8                      Susan Boyle               8.30       [199]
# 9                           Eminem               5.70       [200]
# 10                           Adele              18.10       [192]
# 11                           Adele               8.30       [201]
# 12                   One Direction               4.00       [202]
# 13                 Artistas varios              10.00       [203]
# 14                           Adele              17.40       [204]
# 15                         Beyoncé               2.50       [205]
# 16                      Ed Sheeran               6.10       [206]
# 17  Hugh Jackman & artistas varios               3.50       [207]
# 18                          Arashi               3.30       [208]
# 19                             BTS               4.80       [209]
# 20                           Adele               4.68       [210]
# 21                        Jay Chou               7.20  [211][212]
# 22                       Seventeen               6.40       [213]
# 23                    Taylor Swift               5.60       [214]
# 24                    Taylor Swift               6.05       [215]
# 25                             NaN                NaN         NaN

# %%
#Comprobamos las columnas del df

df_a.columns
# Out:
# Index(['Año', 'Álbum', 'Artista(s)', 'Ventas (millones)', 'Ref(s)'], dtype='object')

# %%
#Comprobamos el tipo de datos que tenemos en el df

df_a.dtypes
# Out:
# Año                  float64
# Álbum                 object
# Artista(s)            object
# Ventas (millones)    float64
# Ref(s)                object
# dtype: object

# %%
#Eliminamos las columnas sin información

df_a = df_a.drop(columns=['Ref(s)'])
df_a
# Out:
#        Año                                      Álbum  \
# 0   2001.0                              Hybrid Theory
# 1   2002.0                            The Eminem Show
# 2   2003.0                          Come Away with Me
# 3   2004.0                                Confessions
# 4   2005.0                                        X&Y
# 5   2006.0                        High School Musical
# 6   2007.0                      High School Musical 2
# 7   2008.0  Viva la Vida or Death and All His Friends
# 8   2009.0                          I Dreamed a Dream
# 9   2010.0                                   Recovery
# 10  2011.0                                         21
# 11  2012.0                                         21
# 12  2013.0                          Midnight Memories
# 13  2014.0                                     Frozen
# 14  2015.0                                         25
# 15  2016.0                                   Lemonade
# 16  2017.0                                          ÷
# 17  2018.0                       The Greatest Showman
# 18  2019.0              5x20 All the Best!! 1999–2019
# 19  2020.0                         Map of the Soul: 7
# 20  2021.0                                         30
# 21  2022.0                      Greatest Works of Art
# 22  2023.0                                        FML
# 23  2024.0              The Tortured Poets Department
# 24  2025.0                     The Life of a Showgirl
# 25     NaN                                        NaN
#
#                         Artista(s)  Ventas (millones)
# 0                      Linkin Park               9.00
# 1                           Eminem              13.90
# 2                      Norah Jones              11.00
# 3                            Usher              12.00
# 4                         Coldplay               8.30
# 5                  Artistas varios               7.00
# 6                  Artistas varios               6.00
# 7                         Coldplay               6.80
# 8                      Susan Boyle               8.30
# 9                           Eminem               5.70
# 10                           Adele              18.10
# 11                           Adele               8.30
# 12                   One Direction               4.00
# 13                 Artistas varios              10.00
# 14                           Adele              17.40
# 15                         Beyoncé               2.50
# 16                      Ed Sheeran               6.10
# 17  Hugh Jackman & artistas varios               3.50
# 18                          Arashi               3.30
# 19                             BTS               4.80
# 20                           Adele               4.68
# 21                        Jay Chou               7.20
# 22                       Seventeen               6.40
# 23                    Taylor Swift               5.60
# 24                    Taylor Swift               6.05
# 25                             NaN                NaN

# %%
#Cambiamos el tipo de número en la columna de ventas

df_a['Ventas (millones)'] = df_a['Ventas (millones)'].astype(float) * 1_000_000
df_a
# Out:
#        Año                                      Álbum  \
# 0   2001.0                              Hybrid Theory
# 1   2002.0                            The Eminem Show
# 2   2003.0                          Come Away with Me
# 3   2004.0                                Confessions
# 4   2005.0                                        X&Y
# 5   2006.0                        High School Musical
# 6   2007.0                      High School Musical 2
# 7   2008.0  Viva la Vida or Death and All His Friends
# 8   2009.0                          I Dreamed a Dream
# 9   2010.0                                   Recovery
# 10  2011.0                                         21
# 11  2012.0                                         21
# 12  2013.0                          Midnight Memories
# 13  2014.0                                     Frozen
# 14  2015.0                                         25
# 15  2016.0                                   Lemonade
# 16  2017.0                                          ÷
# 17  2018.0                       The Greatest Showman
# 18  2019.0              5x20 All the Best!! 1999–2019
# 19  2020.0                         Map of the Soul: 7
# 20  2021.0                                         30
# 21  2022.0                      Greatest Works of Art
# 22  2023.0                                        FML
# 23  2024.0              The Tortured Poets Department
# 24  2025.0                     The Life of a Showgirl
# 25     NaN                                        NaN
#
#                         Artista(s)  Ventas (millones)
# 0                      Linkin Park          9000000.0
# 1                           Eminem         13900000.0
# 2                      Norah Jones         11000000.0
# 3                            Usher         12000000.0
# 4                         Coldplay          8300000.0
# 5                  Artistas varios          7000000.0
# 6                  Artistas varios          6000000.0
# 7                         Coldplay          6800000.0
# 8                      Susan Boyle          8300000.0
# 9                           Eminem          5700000.0
# 10                           Adele         18100000.0
# 11                           Adele          8300000.0
# 12                   One Direction          4000000.0
# 13                 Artistas varios         10000000.0
# 14                           Adele         17400000.0
# 15                         Beyoncé          2500000.0
# 16                      Ed Sheeran          6100000.0
# 17  Hugh Jackman & artistas varios          3500000.0
# 18                          Arashi          3300000.0
# 19                             BTS          4800000.0
# 20                           Adele          4680000.0
# 21                        Jay Chou          7200000.0
# 22                       Seventeen          6400000.0
# 23                    Taylor Swift          5600000.0
# 24                    Taylor Swift          6050000.0
# 25                             NaN                NaN

# %%
#Renombramos las columnas para que sean más claras

df_a.rename(columns={'Ventas (millones)': 'ventas'}, inplace=True)

# %%
df_a
# Out:
#        Año                                      Álbum  \
# 0   2001.0                              Hybrid Theory
# 1   2002.0                            The Eminem Show
# 2   2003.0                          Come Away with Me
# 3   2004.0                                Confessions
# 4   2005.0                                        X&Y
# 5   2006.0                        High School Musical
# 6   2007.0                      High School Musical 2
# 7   2008.0  Viva la Vida or Death and All His Friends
# 8   2009.0                          I Dreamed a Dream
# 9   2010.0                                   Recovery
# 10  2011.0                                         21
# 11  2012.0                                         21
# 12  2013.0                          Midnight Memories
# 13  2014.0                                     Frozen
# 14  2015.0                                         25
# 15  2016.0                                   Lemonade
# 16  2017.0                                          ÷
# 17  2018.0                       The Greatest Showman
# 18  2019.0              5x20 All the Best!! 1999–2019
# 19  2020.0                         Map of the Soul: 7
# 20  2021.0                                         30
# 21  2022.0                      Greatest Works of Art
# 22  2023.0                                        FML
# 23  2024.0              The Tortured Poets Department
# 24  2025.0                     The Life of a Showgirl
# 25     NaN                                        NaN
#
#                         Artista(s)      ventas
# 0                      Linkin Park   9000000.0
# 1                           Eminem  13900000.0
# 2                      Norah Jones  11000000.0
# 3                            Usher  12000000.0
# 4                         Coldplay   8300000.0
# 5                  Artistas varios   7000000.0
# 6                  Artistas varios   6000000.0
# 7                         Coldplay   6800000.0
# 8                      Susan Boyle   8300000.0
# 9                           Eminem   5700000.0
# 10                           Adele  18100000.0
# 11                           Adele   8300000.0
# 12                   One Direction   4000000.0
# 13                 Artistas varios  10000000.0
# 14                           Adele  17400000.0
# 15                         Beyoncé   2500000.0
# 16                      Ed Sheeran   6100000.0
# 17  Hugh Jackman & artistas varios   3500000.0
# 18                          Arashi   3300000.0
# 19                             BTS   4800000.0
# 20                           Adele   4680000.0
# 21                        Jay Chou   7200000.0
# 22                       Seventeen   6400000.0
# 23                    Taylor Swift   5600000.0
# 24                    Taylor Swift   6050000.0
# 25                             NaN         NaN

# %% [markdown]
# ## 🎈 3. Ejercicio beautiful soup🎈

# %% [markdown]
# - Beautiful Soup: scrapear la tabla de lenguajes de programación más utilizados (https://www.tiobe.com/tiobe-index/) creando un dataframe con una columna llamada "lenguaje" y otra columna llamada "porcentaje_uso" (cogiendo la info de programming language y ratings respectivamente).

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
# URL
url = 'https://www.tiobe.com/tiobe-index/'

# Simulamos un navegador para evitar el error 403
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/123.0 Safari/537.36'
}

# Realizar la solicitud GET con el User-Agent especificado
response = requests.get(url, headers=headers)

if response.status_code == 200:
    print(f"status_code: {response.status_code}")
    # Convertir el HTML en un archivo de html
    soup = bs(response.text, 'html.parser')
else:
    print(f"Error: {response.status_code}")
# Out:
# status_code: 200

# %%
# soup es un tipo de dato propio de bs
# representa un HTML parseado
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <title>\n   TIOBE Index - TIOBE\n  </title>\n  <link href="http://gmpg.org/xfn/11" rel="profile"/>\n  <link href="https://www.tiobe.com/wp-content/themes/tiobe/style.css" media="screen" rel="stylesheet" type="text/css"/>\n  <link href="https://www.tiobe.com/xmlrpc.php" rel="pingback"/>\n  <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>\n  <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/site.webmanifest" rel="manifest"/>\n  <link color="#287ac8" href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/safari-pinned-tab.svg" rel="mask-icon"/>\n  <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/favicon.ico" rel="shortcut icon"/>\n  <meta content="#ffffff" name="msapplication-TileColor"/>\n  <meta content="https://www.tiobe.com/wp-content/themes/tiobe/favicon/browserconfig.xml" name="msapplication-config"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->\n  <!--[if lt IE 9]>\n\t<script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\n\t<script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\n\t<![endif]-->\n  <script type="text/javascript">\n   window.dataLayer = window.dataLayer || [];\n\n\tfunction gtag() {\n\t\tdataLayer.push(arguments);\n\t}\n\n\tgtag("consent", "default", {\n\t\tad_personalization: "denied",\n\t\tad_storage: "denied",\n\t\tad_user_data: "denied",\n\t\tanalytics_storage: "denied",\n\t\tfunctionality_storage: "denied",\n\t\tpersonalization_storage: "denied",\n\t\tsecurity_storage: "granted",\n\t\twait_for_update: 500,\n\t});\n\tgtag("set", "ads_data_redaction", true);\n  </script>\n  <script type="text/javascript">\n   (function (w, d, s, l, i) {\n\t\tw[l] = w[l] || [];\n\t\tw[l].push({\'gtm.start\': new Date().getTime(), event: \'gtm.js\'});\n\t\tvar f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l !== \'dataLayer\' ? \'&l=\' + l : \'\';\n\t\tj.async = true;\n\t\tj.src = \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\n\t\tf.parentNode.insertBefore(j, f);\n\t})(\n\t\twindow,\n\t\tdocument,\n\t\t\'script\',\n\t\t\'dataLayer\',\n\t\t\'GTM-P5LV767\'\n\t);\n  </script>\n  <script async="" data-cbid="d715952c-d0b8-4f9e-afee-b0da55c6f179" data-culture="EN" data-implementation="wp" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript">\n  </script>\n  <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">\n   <!-- This site is optimized with the Yoast SEO plugin v27.0 - https://yoast.com/product/yoast-seo-wordpress/ -->\n   <link href="https://www.tiobe.com/tiobe-index/" rel="canonical">\n    <meta content="en_US" property="og:locale">\n     <meta content="article" property="og:type">\n      <meta content="TIOBE Index - TIOBE" property="og:title"/>\n      <meta content="https://www.tiobe.com/tiobe-index/" property="og:url"/>\n      <meta content="TIOBE" property="og:site_name"/>\n      <meta content="2022-06-03T14:27:04+00:00" property="article:modified_time"/>\n      <meta content="summary_large_image" name="twitter:card"/>\n      <meta content="Est. reading time" name="twitter:label1"/>\n      <meta content="3 minutes" name="twitter:data1"/>\n      <script class="yoast-schema-graph" type="application/ld+json">\n       {"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://www.tiobe.com/tiobe-index/","url":"https://www.tiobe.com/tiobe-inde ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>TIOBE Index - TIOBE</title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.tiobe.com/wp-content/themes/tiobe/style.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://www.tiobe.com/xmlrpc.php" rel="pingback"/>
# <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/site.webmanifest" rel="manifest"/>
# <link color="#287ac8" href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/favicon.ico" rel="shortcut icon"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="https://www.tiobe.com/wp-content/themes/tiobe/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# 	<script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# 	<script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
# 	<![endif]-->
# <script type="text/javascript">
# 	window.dataLayer = window.dataLayer || [];
#
# 	function gtag() {
# 		dataLayer.push(arguments);
# 	}
#
# 	gtag("consent", "default", {
# 		ad_personalization: "denied",
# 		ad_storage: "denied",
# 		ad_user_data: "denied",
# 		analytics_storage: "denied",
# 		functionality_storage: "denied",
# 		personalization_storage: "denied",
# 		security_storage: "granted",
# 		wait_for_update: 500,
# 	});
# 	gtag("set", "ads_data_redaction", true);
# 	</script>
# <script type="text/javascript">
# 		(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
# 		var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l !== 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(
# 		window,
# 		document,
# 		'script',
# 		'dataLayer',
# 		'GTM-P5LV767'
# 	);
# </script>
# <script async="" data-cbid="d715952c-d0b8-4f9e-afee-b0da55c6f179" data-culture="EN" data-implementation="wp" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript"></script>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <!-- This site is optimized with the Yoast SEO plugin v27.0 - https://yoast.com/product/yoast-seo-wordpress/ -->
# <link href="https://www.tiobe.com/tiobe-index/" rel="canonical">
# <meta content="en_US" property="og:locale">
# <meta content="article" property="og:type">
# <meta content="TIOBE Index - TIOBE" property="og:title"/>
# <meta content="https://www.tiobe.com/tiobe-index/" property="og:url"/>
# <meta content="TIOBE" property="og:site_name"/>
# <meta content="2022-06-03T14:27:04+00:00" property="article:modified_time"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Est. reading time" name="twitter:label1"/>
# <meta content="3 minutes" name="twitter:data1"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://www.tiobe.com/tiobe-index/","url":"https://www.tiobe.com/tiobe-index/","name":"TIOBE Index - TIOBE","isPartOf":{"@id":"https://www.tiobe.com/#website"},"datePublished":"2021-12-27T15:46:12+00:00","dateModified":"2022-06-03T14:27:04+00:00","description":"TIOBE index programming languages describes the monthly ranking of programming languages on popularity. Top 3 is Python, C, Java","breadcrumb":{"@id":"https://www.tiobe.com/tiobe-index/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://www.tiobe.com/tiobe-index/"]}]},{"@type":"BreadcrumbList","@id":"https://www.tiobe.com/tiobe-index/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.tiobe.com/"},{"@type":"ListItem","position":2,"name":"TIOBE Index"}]},{"@type":"WebSite","@id":"https://www.tiobe.com/#website","url":"https://www.tiobe.com/","name":"TIOBE","description":"","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.tiobe.com/?s={search_term_string}"},"query-input":{"@type":"PropertyValueSpecification","valueRequired":true,"valueName":"search_term_string"}}],"inLanguage":"en-US"}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//code.highcharts.com" rel="dns-prefetch">
# <style id="wp-img-auto-sizes-contain-inline-css">
# img:is([sizes=auto i],[sizes^="auto," i]){contain-intrinsic-size:3000px 1500px}
# /*# sourceURL=wp-img-auto-sizes-contain-inline-css */
# </style>
# <style id="classic-theme-styles-inline-css">
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# /*# sourceURL=/wp-includes/css/classic-themes.min.css */
# </style>
# <link href="https://www.tiobe.com/wp-content/themes/tiobe/css/plugins.min.css?ver=6.9.4" id="Css-plugins-css" media="all" rel="stylesheet">
# <link href="https://www.tiobe.com/wp-content/uploads/wp-less/tiobe/css/style-27410e71f8.css" id="Less-Stylesheet-css" media="all" rel="stylesheet">
# <script id="jQuery-root-js" src="https://www.tiobe.com/wp-content/themes/tiobe/js/jquery.min.js?ver=1.0.0"></script>
# <script id="highcharts-js" src="//code.highcharts.com/highcharts.js?ver=1.0.0"></script>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Titillium+Web:wght@600;700&amp;family=Work+Sans:wght@400;500;600;700&amp;display=block" rel="stylesheet"/>
# <link href="https://www.tiobe.com/wp-content/uploads/2022/06/cropped-android-chrome-512x512-1-32x32.png" rel="icon" sizes="32x32">
# <link href="https://www.tiobe.com/wp-content/uploads/2022/06/cropped-android-chrome-512x512-1-192x192.png" rel="icon" sizes="192x192">
# <link href="https://www.tiobe.com/wp-content/uploads/2022/06/cropped-android-chrome-512x512-1-180x180.png" rel="apple-touch-icon">
# <meta content="https://www.tiobe.com/wp-content/uploads/2022/06/cropped-android-chrome-512x512-1-270x270.png" name="msapplication-TileImage"/>
# </link></link></link></link></link></link></meta></meta></link></meta></head>
# <body class="wp-singular page-template page-template-page-index page-template-page-index-php page page-id-1182 wp-theme-tiobe kleine-golf">
# <div id="old-ie-banner">
# <div class="container">
# <p><b>Let op!</b> Internet Explorer wordt niet meer ondersteund. Hierdoor kan de website mogelijk niet goed functioneren, gebruik een alternatieve browser om optimaal gebruik te maken van deze website. <a class="text-link" href="http://outdatedbrowser.com/nl" target="_blank">Klik hier om een alternatieve browser te downloaden</a>.</p>
# </div>
# </div>
# <header>
# <!--Start Header-->
# <div class="header-top">
# <div class="container">
# <div class="header-inner">
# <div class="logo">
# <a aria-label="TIOBE Software BV" class="logolink" href="https://www.tiobe.com"><img alt="TIOBE the software quality company logo" src="https://www.tiobe.com/wp-content/uploads/2021/11/logo-tiobe.svg"/></a> </div>
# <div class="navigation">
# <div class="top-nav d-none d-lg-flex">
# <ul class="menu" id="menu-top-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1045" id="menu-item-1045"><a href="https://www.tiobe.com/about-us/">About us</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2731" id="menu-item-2731"><a href="https://www.tiobe.com/knowledge/">Knowledge</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1044" id="menu-item-1044"><a href="https://www.tiobe.com/news/">News</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1042" id="menu-item-1042"><a href="https://www.tiobe.com/coding-standards/">Coding Standards</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-1182 current_page_item menu-item-1184" id="menu-item-1184"><a aria-current="page" href="https://www.tiobe.com/tiobe-index/">TIOBE Index</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1046" id="menu-item-1046"><a href="https://www.tiobe.com/contact/">Contact</a></li>
# </ul> <a class="search-trigger" href="#"></a>
# </div>
# <nav class="nav d-none d-md-flex">
# <ul class="menu" id="menu-hoofdmenu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-1049" id="menu-item-1049"><a href="https://www.tiobe.com/products/">Products</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1159" id="menu-item-1159"><a href="https://www.tiobe.com/products/tics/">TiCS Framework</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1334" id="menu-item-1334"><a href="https://www.tiobe.com/products/tics-fact-sheet/">TiCS Fact Sheet</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1176" id="menu-item-1176"><a href="https://www.tiobe.com/products/tqi-quality-assessment/">TQI Code Quality Assessment</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3404" id="menu-item-3404"><a href="https://www.tiobe.com/products/software-composition-analysis/">Software Composition Analysis</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-1162" id="menu-item-1162"><a href="https://www.tiobe.com/quality-models/">Quality Models</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1171" id="menu-item-1171"><a href="https://www.tiobe.com/quality-models/tqi/">TIOBE Quality Indicator</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1170" id="menu-item-1170"><a href="https://www.tiobe.com/quality-models/trusted-product-maintainability/">Trusted Product Maintainability</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-1047" id="menu-item-1047"><a href="https://www.tiobe.com/markets/">Markets</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1166" id="menu-item-1166"><a href="https://www.tiobe.com/markets/customers/">Customers</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1163" id="menu-item-1163"><a href="https://www.tiobe.com/markets/distributors/">Distributors</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2606" id="menu-item-2606"><a href="https://www.tiobe.com/markets/partners/">Partners</a></li>
# </ul>
# </li>
# </ul> <a class="button d-none d-md-inline-block small white highlight" href="https://www.tiobe.com/request-a-demo/" rel="" target="_self">Schedule a demo</a>
# </nav>
# <a class="search-trigger d-none d-md-inline-block d-lg-none" href="#"></a>
# <div class="nav-toggle d-block d-lg-none">
# <div class="hamburger-menu">
# <div class="menu-part"></div>
# <div class="menu-part"></div>
# <div class="menu-part"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="search-bar-item">
# <div class="search-bar-item-inner">
# <div class="container">
# <form action="https://www.tiobe.com/" class="searchform" method="get" role="search">
# <input class="search-field" name="s" placeholder="Start typing to search" type="text" value=""/>
# <div class="submit-container">
# <input class="search-button button blue dark small search-icon" type="submit" value="Search"/>
# </div>
# </form> </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <section class="website-content">
# <div class="tiobe-index container">
# <article class="content">
# <p id="breadcrumbs"><span><span><a href="https://www.tiobe.com/">Home</a></span> » <span aria-current="page" class="breadcrumb_last"><strong>TIOBE Index</strong></span></span></p> <link href="/wp-content/themes/tiobe/tpci/css/tpci.css" rel="stylesheet"/>
# <style type="text/css">
# table.table-top20 tbody tr td {
#   vertical-align: baseline;
# }
#
# td.td-top20 {
#   text-align: center;
# }
#
# table.table-top20 tbody tr:hover td {
#   background-color: lightgrey;
# 	font-weight: bold;
#   cursor: pointer;
#   vertical-align: baseline;
# }
#
# table.table-top20 tbody tr td img {
#     vertical-align: top;
# }
# </style>
# <script>
# $(document).ready(function () {
# $('table.table-top20 > tbody > tr').click(function() {
#   var lang = $(this).find($("td:nth-child(5)")).text();
#   var page = encodeURIComponent(lang);
#
#   window.open("/tiobe-index/?slug=" + page, "_self");
#   });
# });
# </script>
# <script>$(function () {
#   $('#container').highcharts({
#     credits: {
# 		  enabled: false
#     },
#     chart: {
#     	type: 'spline'
#     },
#     plotOptions: {
#     	spline: {
#     		lineWidth: 4,
#     		states: {
#     			hover: {
#     				lineWidth: 5
#     			}
#     		},
#     		marker: {
#     			enabled: false
#     		}
#     	}
#     },
#     title: {
#     	text: 'TIOBE Programming Community Index',
#     	x: -20,
#     	useHTML: true
#     },
#     subtitle: {
#     	text: 'Source: www.tiobe.com',
#     	x: -20,
#     	useHTML: true
#     },
#     xAxis: {
#     	type: 'datetime',
#     	dateTimeLabelFormats: {
#     		year: '%Y'
#     	}
#     },
#     yAxis: {
#       min: 0,
#     	title: {
#     		text: 'Ratings (%)'
#     	},
#     	plotLines: [{
#     		value: 0,
#     		width: 1,
#     		color: '#808080'
#     	}]
#     },
#     tooltip: {
#     	valueSuffix: '%',
#     	dateTimeLabelFormats: {
#     		week: "%B %Y"
#     	}
#     },
#     legend: {
#       align: 'center',borderWidth: 0,
#     },
#     series: [
#     	{name : 'Python',data : [[Date.UTC(2001, 5, 30), 1.25], [Date.UTC(2001, 6, 30), 1.13], [Date.UTC(2001, 7, 30), 1.20], [Date.UTC(2001, 8, 28), 1.17], [Date.UTC(2001, 9, 26), 1.28], [Date.UTC(2001, 10, 28), 1.23], [Date.UTC(2001, 11, 31), 1.04], [Date.UTC(2002, 0, 30), 1.02], [Date.UTC(2002, 1, 27), 0.99], [Date.UTC(2002, 2, 29), 0.99], [Date.UTC(2002, 3, 29), 1.07], [Date.UTC(2002, 4, 29), 1.06], [Date.UTC(2002, 5, 29), 1.13], [Date.UTC(2002, 6, 31), 1.08], [Date.UTC(2002, 7, 29), 1.22], [Date.UTC(2002, 8, 29), 1.08], [Date.UTC(2002, 9, 30), 1.19], [Date.UTC(2002, 10, 29), 1.00], [Date.UTC(2002, 11, 31), 1.00], [Date.UTC(2003, 0, 31), 1.03], [Date.UTC(2003, 1, 28), 0.97], [Date.UTC(2003, 2, 31), 0.99], [Date.UTC(2003, 3, 30), 1.01], [Date.UTC(2003, 4, 30), 1.16], [Date.UTC(2003, 5, 30), 1.28], [Date.UTC(2003, 6, 31), 1.30], [Date.UTC(2003, 7, 31), 1.42], [Date.UTC(2003, 8, 30), 1.49], [Date.UTC(2003, 9, 31), 1.77], [Date.UTC(2003, 10, 30), 1.10], [Date.UTC(2003, 11, 31), 1.13], [Date.UTC(2004, 0, 31), 1.01], [Date.UTC(2004, 1, 29), 1.02], [Date.UTC(2004, 2, 31), 1.01], [Date.UTC(2004, 3, 30), 4.57], [Date.UTC(2004, 4, 30), 6.58], [Date.UTC(2004, 5, 30), 4.96], [Date.UTC(2004, 6, 31), 4.70], [Date.UTC(2004, 7, 30), 5.60], [Date.UTC(2004, 8, 30), 4.44], [Date.UTC(2004, 9, 31), 5.20], [Date.UTC(2004, 10, 30), 3.03], [Date.UTC(2004, 11, 31), 2.84], [Date.UTC(2005, 0, 31), 2.51], [Date.UTC(2005, 1, 28), 2.42], [Date.UTC(2005, 2, 31), 2.70], [Date.UTC(2005, 3, 30), 2.48], [Date.UTC(2005, 4, 31), 2.80], [Date.UTC(2005, 5, 30), 2.52], [Date.UTC(2005, 6, 31), 2.88], [Date.UTC(2005, 7, 31), 3.03], [Date.UTC(2005, 8, 30), 2.88], [Date.UTC(2005, 11, 3), 2.68], [Date.UTC(2006, 0, 4), 2.60], [Date.UTC(2006, 1, 2), 2.67], [Date.UTC(2006, 2, 1), 3.09], [Date.UTC(2006, 3, 2), 2.76], [Date.UTC(2006, 4, 1), 3.04], [Date.UTC(2006, 5, 1), 3.46], [Date.UTC(2006, 6, 2), 3.02], [Date.UTC(2006, 7, 2), 3.07], [Date.UTC(2006, 8, 2), 3.14], [Date.UTC(2006, 9, 1), 3.47], [Date.UTC(2006, 10, 2), 3.64], [Date.UTC(2006, 11, 1), 3.76], [Date.UTC(2007, 0, 2), 3.50], [Date.UTC(2007, 1, 3), 3.57], [Date.UTC(2007, 2, 3), 3.90], [Date.UTC(2007, 3, 1), 3.81], [Date.UTC(2007, 4, 5), 3.78], [Date.UTC(2007, 5, 2), 3.16], [Date.UTC(2007, 6, 2), 3.02], [Date.UTC(2007, 7, 5), 2.75], [Date.UTC(2007, 8, 2), 3.03], [Date.UTC(2007, 9, 4), 3.43], [Date.UTC(2007, 10, 4), 4.23], [Date.UTC(2007, 11, 3), 4.70], [Date.UTC(2008, 0, 3), 5.54], [Date.UTC(2008, 1, 7), 4.76], [Date.UTC(2008, 5, 1), 4.90], [Date.UTC(2008, 6, 2), 4.97], [Date.UTC(2008, 7, 3), 4.98], [Date.UTC(2008, 8, 3), 5.01], [Date.UTC(2008, 9, 6), 4.56], [Date.UTC(2008, 10, 2), 5.14], [Date.UTC(2008, 11, 3), 4.17], [Date.UTC(2009, 0, 2), 4.73], [Date.UTC(2009, 1, 1), 4.57], [Date.UTC(2009, 2, 5), 5.18], [Date.UTC(2009, 3, 7), 6.08], [Date.UTC(2009, 4, 1), 5.55], [Date.UTC(2009, 5, 4), 4.76], [Date.UTC(2009, 6, 2), 4.43], [Date.UTC(2009, 7, 1), 4.49], [Date.UTC(2009, 8, 5), 3.93], [Date.UTC(2009, 9, 2), 3.90], [Date.UTC(2009, 10, 2), 4.67], [Date.UTC(2009, 11, 2), 5.19], [Date.UTC(2010, 0, 5), 4.45], [Date.UTC(2010, 1, 7), 4.31], [Date.UTC(2010, 2, 7), 4.23], [Date.UTC(2010, 3, 5), 4.21], [Date.UTC(2010, 4, 15), 4.10], [Date.UTC(2010, 6, 6), 4.22], [Date.UTC(2010, 6, 30), 4.22], [Date.UTC(2010, 8, 11), 4.58], [Date.UTC(2010, 9, 2), 4.86], [Date.UTC(2010, 10, 3), 5.68], [Date.UTC(2010, 11, 7), 6.48], [Date.UTC(2011, 0, 2), 6.26], [Date.UTC(2011, 1, 8), 7.04], [Date.UTC(2011, 2, 8), 5.74], [Date.UTC(2011, 3, 3), 4.93], [Date.UTC(2011, 4, 2), 4.58], [Date.UTC(2011, 5, 5), 3.90], [Date.UTC(2011, 5, 27), 3.90], [Date.UTC(2011, 6, 8), 3.58], [Date.UTC(2011, 7, 3), 3.41], [Date.UTC(2011, 8, 10), 4.00], [Date.UTC(2011, 9, 9), 3.94], [Date.UTC(2011, 10, 7), 3.62], [Date.UTC(2011, 11, 4), 3.49], [Date.UTC(2012, 0, 8), 3.21], [Date.UTC(2012, 1, 5), 3.15], [Date.UTC(2012, 2, 11), 3.29], [Date.UTC(2012, 3, 8), 3.66], [Date.UTC(2012, 4, 9), 3.82], [Date.UTC(2012, 5, 10), 3.85], [Date.UTC(2012, 6, 4), 4.00], [Date.UTC(2012, 7, 1 ...
#     ]
#   });
# });
# </script>
# <h1><b>TIOBE Index for May 2026</b></h1>
# <h3>May Headline: Statistical Programming Language Market Undergoing Major Consolidation</h3>
# <p>
# This month, the programming language R matched its all-time high by reaching position #8 in the TIOBE index once again. This is not a coincidence. The statistical programming language market is clearly undergoing a major consolidation. The biggest winners are Python and R, while many long-established alternatives continue to lose momentum. The era in which the statistical computing landscape was fragmented across many niche languages and platforms appears to be coming to an end.
# </p><p>
# Several established players are steadily declining:
# <ul>
# <li>
# MATLAB is close to dropping out of the TIOBE top 20.
# </li>
# <li>
# SAS is about to leave the top 30 for the first time since the TIOBE index began.
# </li>
# <li>
# Wolfram/Mathematica remains well below its historical peak and is losing further ground.
# </li>
# <li>
# SPSS dropped out of the top 100 last month.
# </li>
# <li>
# S is also close to leaving the top 100.
# </li>
# <li>
# Stata currently sits at position #124.
# </li>
# </ul>
# </p><p>
# Meanwhile, the newer statistical language Julia has struggled for years to establish itself as a stable top-30 language despite strong technical merits and growing academic interest. Looking ahead, Stan is expected to debut in the TIOBE index next month, reflecting the growing importance of probabilistic programming and Bayesian statistics.
# </p><p>
# In practice, today’s statistical programming market increasingly revolves around just two dominant ecosystems:
# </p><p>
# <ul><li>
# Python dominates industry, machine learning, AI, and production systems.
# </li><li>
# R remains the leading environment in academia, research, epidemiology, and advanced statistical analysis.
# </li></ul>
# </p><p>
# Elsewhere in the index, Java and C++ swapped positions this month. Java gained momentum following the successful release of Java 26. Another notable riser is Zig, which is approaching the TIOBE top 30 for the first time. Zig’s growing popularity appears to be driven by its rare combination of low-level performance, straightforward tooling, and relative ease of use compared to traditional systems programming languages.
# </p>
# <div class="default-block authors">
# <div class="row">
# <div class="col-12">
# <div class="author-title">
# <h3>Author:</h3>
# </div>
# </div>
# <div class="col-lg-8 col-xl-6">
# <div class="authors-wrapper single-author">
# <div class="row">
# <div class="col-12">
# <div class="author">
# <div class="author-image">
# <img alt="Author Paul Jansen" src="https://www.tiobe.com/wp-content/uploads/2024/08/Paul_LinkedIn.jpeg"/>
# </div>
# <div class="author-info">
# <h3 class="author-name">Paul Jansen</h3>
# <span class="author-function">Chief Executive Officer</span>
# <a class="author-linkedin" href="https://www.linkedin.com/in/paul-jansen-299429/" rel="noopener" target="_blank" title="Follow [AUTEUR NAAM] on LinkedIn">Follow <span>Paul Jansen</span> on LinkedIn</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <p>The TIOBE Programming Community index is an indicator of the popularity of programming
# languages. The index is updated once a month. The ratings are based on the number of
# skilled engineers world-wide, courses and third party vendors. Popular web sites
# Google, Amazon, Wikipedia, Bing and more than 20 others are used to calculate the ratings.
# It is important to note that the TIOBE index is not about the <i>best</i> programming language or the language
# in which <i>most lines of code</i> have been written.</p>
# <p>The index can be used to check whether your programming skills are still up to date or to make a
# strategic decision about what programming language should be adopted when starting to build a new
# software system. The definition of the TIOBE index can be found <a href="/tiobe-index/programminglanguages_definition">here</a>.
# </p>
# <table class="table table-striped table-top20" id="top20">
# <thead><tr>
# <th style="width: 15%">May 2026</th>
# <th style="width: 15%">May 2025</th>
# <th style="width: 15%" title="Difference compared to last year">Change</th>
# <th colspan="2" style="width: 25%">Programming Language</th>
# <th style="width: 15%">Ratings</th>
# <th style="width: 15%" title="Difference compared to last year">Change</th>
# </tr></thead>
# <tbody>
# <tr><td>1</td><td>1</td><td></td><td class="td-top20"><img alt="Python page" src="/wp-content/themes/tiobe/tiobe-index/images/Python.png" style="vertical-align:middle"/></td><td>Python</td><td>19.98%</td><td>-5.37%</td></tr><tr><td>2</td><td>3</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/up.png"/></td><td class="td-top20"><img alt="C page" src="/wp-content/themes/tiobe/tiobe-index/images/C.png" style="vertical-align:middle"/></td><td>C</td><td>11.55%</td><td>+1.84%</td></tr><tr><td>3</td><td>4</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/up.png"/></td><td class="td-top20"><img alt="Java page" src="/wp-content/themes/tiobe/tiobe-index/images/Java.png" style="vertical-align:middle"/></td><td>Java</td><td>7.94%</td><td>-1.37%</td></tr><tr><td>4</td><td>2</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/down.png"/></td><td class="td-top20"><img alt="C++ page" src="/wp-content/themes/tiobe/tiobe-index/images/C__.png" style="vertical-align:middle"/></td><td>C++</td><td>7.92%</td><td>-2.02%</td></tr><tr><td>5</td><td>5</td><td></td><td class="td-top20"><img alt="C# page" src="/wp-content/themes/tiobe/tiobe-index/images/C_.png" style="vertical-align:middle"/></td><td>C#</td><td>5.41%</td><td>+1.19%</td></tr><tr><td>6</td><td>6</td><td></td><td class="td-top20"><img alt="JavaScript page" src="/wp-content/themes/tiobe/tiobe-index/images/JavaScript.png" style="vertical-align:middle"/></td><td>JavaScript</td><td>3.08%</td><td>-0.60%</td></tr><tr><td>7</td><td>8</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/up.png"/></td><td class="td-top20"><img alt="Visual Basic page" src="/wp-content/themes/tiobe/tiobe-index/images/Visual_Basic.png" style="vertical-align:middle"/></td><td>Visual Basic</td><td>2.90%</td><td>+0.28%</td></tr><tr><td>8</td><td>12</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/upup.png"/></td><td class="td-top20"><img alt="R page" src="/wp-content/themes/tiobe/tiobe-index/images/R.png" style="vertical-align:middle"/></td><td>R</td><td>1.77%</td><td>+0.31%</td></tr><tr><td>9</td><td>10</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/up.png"/></td><td class="td-top20"><img alt="SQL page" src="/wp-content/themes/tiobe/tiobe-index/images/SQL.png" style="vertical-align:middle"/></td><td>SQL</td><td>1.57%</td><td>-0.33%</td></tr><tr><td>10</td><td>9</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/down.png"/></td><td class="td-top20"><img alt="Delphi/Object Pascal page" src="/wp-content/themes/tiobe/tiobe-index/images/Delphi_Object_Pascal.png" style="vertical-align:middle"/></td><td>Delphi/Object Pascal</td><td>1.44%</td><td>-0.85%</td></tr><tr><td>11</td><td>11</td><td></td><td class="td-top20"><img alt="Fortran page" src="/wp-content/themes/tiobe/tiobe-index/images/Fortran.png" style="vertical-align:middle"/></td><td>Fortran</td><td>1.22%</td><td>-0.55%</td></tr><tr><td>12</td><td>14</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/up.png"/></td><td class="td-top20"><img alt="Scratch page" src="/wp-content/themes/tiobe/tiobe-index/images/Scratch.png" style="vertical-align:middle"/></td><td>Scratch</td><td>1.18%</td><td>-0.16%</td></tr><tr><td>13</td><td>16</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/up.png"/></td><td class="td-top20"><img alt="Perl page" src="/wp-content/themes/tiobe/tiobe-index/images/Perl.png" style="vertical-align:middle"/></td><td>Perl</td><td>1.18%</td><td>-0.02%</td></tr><tr><td>14</td><td>15</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/up.png"/></td><td class="td-top20"><img alt="PHP page" src="/wp-content/themes/tiobe/tiobe-index/images/PHP.png" style="vertical-align:middle"/></td><td>PHP</td><td>1.15%</td><td>-0.07%</td></tr><tr><td>15</td><td>19</td><td><img alt="change" src="/wp-content/themes/tiobe/tpci/images/upup.png"/></td><td class="td-top20"><img alt="Rust page" src="/wp-content/themes/ ...
# </tbody>
# </table>
# <div id="container" style="width:100%; height:450px;"></div>
# <hr/>
# <h2>Other programming languages</h2>
# <p>The complete top 50 of programming languages is listed below. This overview is
# published unofficially, because it could be the case that we missed a language. If
# you have the impression there is a programming language lacking, please notify us
# at <a href="mailto:tpci@tiobe.com">tpci@tiobe.com</a>. Please also check the <a href="programminglanguages_definition#instances">overview of all programming languages</a> that we monitor.</p>
# <table class="table table-striped" id="otherPL">
# <thead><tr><th>Position</th><th>Programming Language</th><th>Ratings</th></tr></thead>
# <tbody>
# <tr><td>21</td><td>Classic Visual Basic</td><td>0.80%</td></tr><tr><td>22</td><td>PL/SQL</td><td>0.79%</td></tr><tr><td>23</td><td>Ruby</td><td>0.73%</td></tr><tr><td>24</td><td>Prolog</td><td>0.71%</td></tr><tr><td>25</td><td>COBOL</td><td>0.65%</td></tr><tr><td>26</td><td>Kotlin</td><td>0.65%</td></tr><tr><td>27</td><td>Objective-C</td><td>0.60%</td></tr><tr><td>28</td><td>SAS</td><td>0.60%</td></tr><tr><td>29</td><td>ML</td><td>0.58%</td></tr><tr><td>30</td><td>Dart</td><td>0.55%</td></tr><tr><td>31</td><td>Lua</td><td>0.51%</td></tr><tr><td>32</td><td>OCaml</td><td>0.46%</td></tr><tr><td>33</td><td>Julia</td><td>0.43%</td></tr><tr><td>34</td><td>Caml</td><td>0.41%</td></tr><tr><td>35</td><td>TypeScript</td><td>0.40%</td></tr><tr><td>36</td><td>Zig</td><td>0.39%</td></tr><tr><td>37</td><td>GML</td><td>0.38%</td></tr><tr><td>38</td><td>LabVIEW</td><td>0.37%</td></tr><tr><td>39</td><td>ABAP</td><td>0.36%</td></tr><tr><td>40</td><td>VBScript</td><td>0.35%</td></tr><tr><td>41</td><td>Lisp</td><td>0.33%</td></tr><tr><td>42</td><td>X++</td><td>0.32%</td></tr><tr><td>43</td><td>Clojure</td><td>0.32%</td></tr><tr><td>44</td><td>D</td><td>0.31%</td></tr><tr><td>45</td><td>Erlang</td><td>0.29%</td></tr><tr><td>46</td><td>Ladder Logic</td><td>0.28%</td></tr><tr><td>47</td><td>Haskell</td><td>0.26%</td></tr><tr><td>48</td><td>Scala</td><td>0.26%</td></tr><tr><td>49</td><td>Transact-SQL</td><td>0.26%</td></tr><tr><td>50</td><td>CFML</td><td>0.23%</td></tr>
# </tbody>
# </table>
# <hr/>
# <h2>The Next 50 Programming Languages</h2>
# <p>The following list of languages denotes #51 to #100. Since the differences are
# relatively small, the programming languages are only listed (in alphabetical
# order).
# </p>
# <ul>
# <li>
# (Visual) FoxPro, ActionScript, Apex, Applescript, Awk, Bash, bc, BCPL, Bourne shell, C shell, CL (OS/400), CoffeeScript, cT, ECMAScript, Elixir, F#, GAMS, Groovy, Io, J, J#, JScript, JScript.NET, Logo, LotusScript, LPC, MDX, MQL5, NetLogo, OpenCL, PL/I, PowerShell, Pure Data, Q, REBOL, Ring, RPG, RPL, S, Scheme, Small Basic, Solidity, Tcl, V, Vala/Genie, VHDL, Wolfram, XC, Xojo, XPL
# </li></ul>
# <hr/>
# <h2>Very Long Term History</h2>
# <p>
# To see the bigger picture, please find below the positions of the top 10 programming languages of many years back. Please note that these are <i>average</i> positions for a period of 12 months.</p>
# <table class="table table-striped" id="VLTH">
# <thead><tr><th>Programming Language</th><th>2026</th><th>2021</th><th>2016</th><th>2011</th><th>2006</th><th>2001</th><th>1996</th><th>1991</th><th>1986</th></tr></thead>
# <tr><td>Python</td><td>1</td><td>3</td><td>5</td><td>6</td><td>8</td><td>27</td><td>19</td><td>-</td><td>-</td></tr><tr><td>C</td><td>2</td><td>1</td><td>2</td><td>2</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>C++</td><td>3</td><td>4</td><td>3</td><td>3</td><td>3</td><td>2</td><td>2</td><td>2</td><td>8</td></tr><tr><td>Java</td><td>4</td><td>2</td><td>1</td><td>1</td><td>1</td><td>3</td><td>26</td><td>-</td><td>-</td></tr><tr><td>C#</td><td>5</td><td>5</td><td>4</td><td>5</td><td>7</td><td>13</td><td>-</td><td>-</td><td>-</td></tr><tr><td>JavaScript</td><td>6</td><td>7</td><td>8</td><td>10</td><td>9</td><td>10</td><td>32</td><td>-</td><td>-</td></tr><tr><td>Visual Basic</td><td>7</td><td>6</td><td>13</td><td>-</td><td>-</td><td>-</td><td>-</td><td>-</td><td>-</td></tr><tr><td>Delphi/Object Pascal</td><td>8</td><td>20</td><td>11</td><td>12</td><td>10</td><td>-</td><td>-</td><td>-</td><td>-</td></tr><tr><td>SQL</td><td>9</td><td>9</td><td>-</td><td>-</td><td>-</td><td>-</td><td>-</td><td>-</td><td>-</td></tr><tr><td>Perl</td><td>10</td><td>15</td><td>9</td><td>9</td><td>5</td><td>5</td><td>4</td><td>-</td><td>-</td></tr><tr><td>Ada</td><td>16</td><td>36</td><td>28</td><td>18</td><td>16</td><td>20</td><td>8</td><td>5</td><td>3</td></tr><tr><td>Lisp</td><td>28</td><td>34</td><td>27</td><td>13</td><td>14</td><td>17</td><td>7</td><td>4</td><td>2</td></tr><tr><td>(Visual) Basic</td><td>-</td><td>-</td><td>-</td><td>7</td><td>6</td><td>4</td><td>3</td><td>3</td><td>5</td></tr>
# </table>
# <p>Important observations:</p>
# <ul>
# <li>Data prior to 2001 are not based on Web search engine counts but based on Usenet's newsgroup hits, which have been calculated retrospectively.</li>
# <li>There is a difference between "Visual Basic" and "(Visual) Basic" in the table above. Until 2010, "(Visual) Basic" referred to all possible dialects of Basic, including Visual Basic. After some discussion, it has been decided to split "(Visual) Basic" into all its dialects such as Visual Basic .NET, Classic Visual Basic, PureBasic, and Small Basic, just to name a few. Since Visual Basic .NET has become the major implementation of Visual Basic, it is now called "Visual Basic".</li>
# <li>The programming language SQL was added to the TIOBE index in 2018 after somebody pointed out that SQL is Turing Complete. So although this language is very old, it has only a short history in the index.</li>
# </ul>
# <hr/>
# <h2>Programming Language Hall of Fame</h2>
# <p>The hall of fame listing all "Programming Language of the Year" award winners is shown below. The award is given to the programming language that has the highest rise in ratings in a year.
# <br/><br/>
# <table class="table table-striped" id="PLHoF"><colgroup><col align="center"/><col align="center"/><tr><th align="center" nowrap="">Year</th><th align="center" nowrap="">Winner</th><tr><td>2025</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> C#</td></tr><tr><td>2024</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Python</td></tr><tr><td>2023</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> C#</td></tr><tr><td>2022</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> C++</td></tr><tr><td>2021</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Python</td></tr><tr><td>2020</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Python</td></tr><tr><td>2019</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> C</td></tr><tr><td>2018</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Python</td></tr><tr><td>2017</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> C</td></tr><tr><td>2016</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Go</td></tr><tr><td>2015</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Java</td></tr><tr><td>2014</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> JavaScript</td></tr><tr><td>2013</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Transact-SQL</td></tr><tr><td>2012</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Objective-C</td></tr><tr><td>2011</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Objective-C</td></tr><tr><td>2010</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Python</td></tr><tr><td>2009</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Go</td></tr><tr><td>2008</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> C</td></tr><tr><td>2007</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Python</td></tr><tr><td>2006</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Ruby</td></tr><tr><td>2005</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> Java</td></tr><tr><td>2004</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> PHP</td></tr><tr><td>2003</td><td><img alt="medal" src="/wp-content/themes/tiobe/tpci/images/medal.png"/> C++</td></tr></tr></colgroup></table>
# </p>
# <hr/>
# <div class="content-tekst">
# <div class="container">
# <div class="row">
# <div class="col-lg-10 col-md-12">
# <div class="kolom kolom-1">
# <div class="tekst">
# <h2>Bugs &amp; Change Requests</h2>
# <p>This is the top 5 of most requested changes and bugs. If you have any suggestions how to improve the index don’t hesitate to send an e-mail to <a href="mailto:tpci@tiobe.com">tpci@tiobe.com</a>.</p>
# <ol>
# <li>Apart from “&lt;language&gt; programming”, also other queries such as “programming with &lt;language&gt;”, “&lt;language&gt; development” and “&lt;language&gt; coding” should be tried out.</li>
# <li>Add queries for other natural languages (apart from English). The idea is to start with the Chinese search engine Baidu. This has been implemented partially and will be completed the next few months.</li>
# <li>Add a list of all search term requests that have been rejected. This is to minimize the number of recurring mails about Rails, JQuery, JSP, etc.</li>
# <li>Start a TIOBE index for databases, software configuration management systems and application frameworks.</li>
# <li>Some search engines allow to query pages that have been added last year. The TIOBE index should only track those recently added pages.</li>
# </ol>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> <div class="faq-blok" itemscope="" itemtype="https://schema.org/FAQPage">
# <div class="container">
# <div class="row">
# <div class="col-md-8 offset-md-2">
# <div class="faq-container">
# <div class="accordion tekst">
# <div class="collapse-item vraag-1" itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
# <div class="titel">
# <h3 class="vraag no-border" itemprop="name">
# <button>Am I allowed to show the TIOBE index in my weblog/presentation/publication?</button>
# </h3>
# <div class="close">
# <svg id="Layer_1" style="enable-background:new 0 0 12 12;" version="1.1" viewbox="0 0 12 12" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <path class="st0" d="M7.4,6l3.5-3.5c0.4-0.4,0.4-1,0-1.4c-0.4-0.4-1-0.4-1.4,0L6,4.6L2.5,1.1c-0.4-0.4-1-0.4-1.4,0
# 								c-0.4,0.4-0.4,1,0,1.4L4.6,6L1.1,9.5c-0.4,0.4-0.4,1,0,1.4c0.4,0.4,1,0.4,1.4,0L6,7.4l3.5,3.5c0.4,0.4,1,0.4,1.4,0
# 								c0.4-0.4,0.4-1,0-1.4L7.4,6z"></path>
# </svg>
# </div>
# </div>
# <div class="collapse-itself" itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
# <div class="antwoord" itemprop="text">
# <p>Yes, the only condition is to refer to its original source “www.tiobe.com”.</p>
# </div>
# </div>
# </div>
# <div class="collapse-item vraag-2" itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
# <div class="titel">
# <h3 class="vraag no-border" itemprop="name">
# <button>How may I nominate a new language to be added to the TIOBE index?</button>
# </h3>
# <div class="close">
# <svg id="Layer_1" style="enable-background:new 0 0 12 12;" version="1.1" viewbox="0 0 12 12" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <path class="st0" d="M7.4,6l3.5-3.5c0.4-0.4,0.4-1,0-1.4c-0.4-0.4-1-0.4-1.4,0L6,4.6L2.5,1.1c-0.4-0.4-1-0.4-1.4,0
# 								c-0.4,0.4-0.4,1,0,1.4L4.6,6L1.1,9.5c-0.4,0.4-0.4,1,0,1.4c0.4,0.4,1,0.4,1.4,0L6,7.4l3.5,3.5c0.4,0.4,1,0.4,1.4,0
# 								c0.4-0.4,0.4-1,0-1.4L7.4,6z"></path>
# </svg>
# </div>
# </div>
# <div class="collapse-itself" itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
# <div class="antwoord" itemprop="text">
# <p>If a language meets the criteria of being listed (i.e. it is Turing complete and has an own Wikipedia entry that indicates that it concerns a programming language) and it is sufficiently popular (more than 5,000 hits for +”&lt;language&gt; programming” for Google), then please write an e-mail to <a href="mailto:tpci@tiobe.com">tpci@tiobe.com</a>.</p>
# </div>
# </div>
# </div>
# <div class="collapse-item vraag-3" itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
# <div class="titel">
# <h3 class="vraag no-border" itemprop="name">
# <button>I would like to have the complete data set of the TIOBE index. Is this possible?</button>
# </h3>
# <div class="close">
# <svg id="Layer_1" style="enable-background:new 0 0 12 12;" version="1.1" viewbox="0 0 12 12" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <path class="st0" d="M7.4,6l3.5-3.5c0.4-0.4,0.4-1,0-1.4c-0.4-0.4-1-0.4-1.4,0L6,4.6L2.5,1.1c-0.4-0.4-1-0.4-1.4,0
# 								c-0.4,0.4-0.4,1,0,1.4L4.6,6L1.1,9.5c-0.4,0.4-0.4,1,0,1.4c0.4,0.4,1,0.4,1.4,0L6,7.4l3.5,3.5c0.4,0.4,1,0.4,1.4,0
# 								c0.4-0.4,0.4-1,0-1.4L7.4,6z"></path>
# </svg>
# </div>
# </div>
# <div class="collapse-itself" itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
# <div class="antwoord" itemprop="text">
# <p>We spent a lot of effort to obtain all the data and keep the TIOBE index up to date. In order to compensate a bit for this, we ask a fee of 5,000 US$ for the complete data set. The data set runs from June 2001 till today. It started with 25 languages back in 2001, and now measures more than 150 languages once a month. The data are available in comma separated format. Please contact <a href="mailto:sales@tiobe.com">sales@tiobe.com</a> for more information.</p>
# </div>
# </div>
# </div>
# <div class="collapse-item vraag-4" itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
# <div class="titel">
# <h3 class="vraag no-border" itemprop="name">
# <button>Why is the maximum taken to calculate the ranking for a grouping, why not the sum?</button>
# </h3>
# <div class="close">
# <svg id="Layer_1" style="enable-background:new 0 0 12 12;" version="1.1" viewbox="0 0 12 12" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <path class="st0" d="M7.4,6l3.5-3.5c0.4-0.4,0.4-1,0-1.4c-0.4-0.4-1-0.4-1.4,0L6,4.6L2.5,1.1c-0.4-0.4-1-0.4-1.4,0
# 								c-0.4,0.4-0.4,1,0,1.4L4.6,6L1.1,9.5c-0.4,0.4-0.4,1,0,1.4c0.4,0.4,1,0.4,1.4,0L6,7.4l3.5,3.5c0.4,0.4,1,0.4,1.4,0
# 								c0.4-0.4,0.4-1,0-1.4L7.4,6z"></path>
# </svg>
# </div>
# </div>
# <div class="collapse-itself" itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
# <div class="antwoord" itemprop="text">
# <p>Well, you can do it either way and both are wrong. If you take the sum, then you get the intersection twice. If you take the max, then you miss the difference. Which one to choose? Suppose somebody comes up with a new search term that is 10% of the original. If you take the max, nothing changes. If you take the sum then the ratings will rise 10%. So taking the sum will be an incentive for some to come up with all kinds of obscure terms for a language. That’s why we decided to take the max.</p>
# <p>The proper way to solve this is is of course to take the sum and subtract the intersection. This will give rise to an explosion of extra queries that must be performed. Suppose a language has a grouping of 15 terms, then you have to perform 32,768 queries (all combinations of intersections). So this seems not possible either… If somebody has a solution for this, please let us know.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </article>
# <div class="cta-blok">
# <div class="container">
# <div class="row">
# <div class="col-lg-10 offset-lg-1">
# <div class="cta-blok-wrapper">
# <div class="cta-blok-background lazy" data-src="https://www.tiobe.com/wp-content/themes/tiobe/images/cta-blok-background.svg"></div>
# <div class="cta-image lazy" data-src="https://www.tiobe.com/wp-content/uploads/2023/08/Laptop_TIOBE.png"></div>
# <div class="tekst">
# <h2>Get your own proof of concept</h2>
# <p>Curious how your projects will be ranked by our TiCS Framework? Request your proof of concept now to discover the quality of your code.</p>
# <a class="button" href="https://www.tiobe.com/request-a-demo/" rel="" target="_self">Request a demo</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# </section>
# <nav class="responsive-nav"><!--Start Responsive Navigatie-->
# <ul class="nav">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-1049"><a href="https://www.tiobe.com/products/">Products</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1159"><a href="https://www.tiobe.com/products/tics/">TiCS Framework</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1334"><a href="https://www.tiobe.com/products/tics-fact-sheet/">TiCS Fact Sheet</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1176"><a href="https://www.tiobe.com/products/tqi-quality-assessment/">TQI Code Quality Assessment</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3404"><a href="https://www.tiobe.com/products/software-composition-analysis/">Software Composition Analysis</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-1162"><a href="https://www.tiobe.com/quality-models/">Quality Models</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1171"><a href="https://www.tiobe.com/quality-models/tqi/">TIOBE Quality Indicator</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1170"><a href="https://www.tiobe.com/quality-models/trusted-product-maintainability/">Trusted Product Maintainability</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-1047"><a href="https://www.tiobe.com/markets/">Markets</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1166"><a href="https://www.tiobe.com/markets/customers/">Customers</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1163"><a href="https://www.tiobe.com/markets/distributors/">Distributors</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2606"><a href="https://www.tiobe.com/markets/partners/">Partners</a></li>
# </ul>
# </li>
# </ul>
# <ul class="nav topnav">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1045"><a href="https://www.tiobe.com/about-us/">About us</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2731"><a href="https://www.tiobe.com/knowledge/">Knowledge</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1044"><a href="https://www.tiobe.com/news/">News</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1042"><a href="https://www.tiobe.com/coding-standards/">Coding Standards</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-1182 current_page_item menu-item-1184"><a aria-current="page" href="https://www.tiobe.com/tiobe-index/">TIOBE Index</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1046"><a href="https://www.tiobe.com/contact/">Contact</a></li>
# </ul>
# <div class="searchform-wrapper">
# <form action="https://www.tiobe.com/" class="searchform d-md-none" method="get" role="search">
# <input class="search-field" name="s" placeholder="Start typing to search" type="text" value=""/>
# <div class="submit-container">
# <input class="search-button button blue dark small search-icon" type="submit" value="Search"/>
# </div>
# </form>
# </div>
# <a class="button d-inline-block d-md-none" href="https://www.tiobe.com/request-a-demo/" rel="" target="_self">Schedule a demo</a>
# </nav>
# <footer>
# <div class="cta-footer">
# <div class="container">
# <div class="cta-footer-item">
# <div class="cta-wrapper">
# <div class="footer-logo lazy" data-src="https://www.tiobe.com/wp-content/uploads/2021/11/logo-tiobe-white.svg"></div>
# <div class="footer-content"><p>TIOBE checks more than 1 billion lines of software code.<br>
# <b>Worldwide, realtime, each day.</b></br></p>
# </div>
# </div>
# <a class="button" href="https://www.tiobe.com/request-a-demo/" rel="" target="_self">Schedule a demo</a>
# </div>
# </div>
# </div>
# <div class="top-footer">
# <div class="container">
# <div class="row">
# <div class="col-md-6 col-lg-6">
# <div class="footer-block menu">
# <p class="titel">Navigation</p>
# <ul class="menu" id="menu-navigation"><li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-1182 current_page_item menu-item-1635" id="menu-item-1635"><a aria-current="page" href="https://www.tiobe.com/tiobe-index/">TIOBE Index</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1638" id="menu-item-1638"><a href="https://www.tiobe.com/products/">Products</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1636" id="menu-item-1636"><a href="https://www.tiobe.com/quality-models/">Quality Models</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1637" id="menu-item-1637"><a href="https://www.tiobe.com/markets/">Markets</a></li>
# </ul> </div>
# </div>
# <div class="col-md-6 col-lg-6">
# <div class="footer-block contact">
# <p class="titel">
# 							Contact us						</p>
# <div class="row">
# <div class="col-6">
# <p class="icons">
# <a href="tel:+31404002800"><span class="lazy" data-src="https://www.tiobe.com/wp-content/themes/tiobe/images/footer-tel.svg"></span>+31 40 400 2800</a><br/>
# <a href="mailto:info@tiobe.com"><span class="lazy" data-src="https://www.tiobe.com/wp-content/themes/tiobe/images/footer-mail.svg"></span>info@tiobe.com</a><br/>
# <a href="https://www.linkedin.com/company/tiobe-software/" rel="noopener" target="_blank"><span class="lazy" data-src="https://www.tiobe.com/wp-content/themes/tiobe/images/footer-linkedin.svg"></span>Connect on LinkedIn</a><br/>
# </p>
# </div>
# <div class="col-6">
# <p>
# 									Telexweg 4 (Hofdael Office Complex)<br/>									5641 TL 									Eindhoven<br/>									The Netherlands 								</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bottom-footer">
# <div class="container">
# <div class="footer-inner">
# <div class="colofon-left">
# <div class="menu-colofon-menu-container"><ul class="menu" id="menu-colofon-menu"><li><p>© 2026 TIOBE Software BV</p></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-948" id="menu-item-948"><a href="https://www.tiobe.com/disclaimer/">Disclaimer</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-306" id="menu-item-306"><a href="https://www.tiobe.com/sitemap/">Sitemap</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-privacy-policy menu-item-305" id="menu-item-305"><a href="https://www.tiobe.com/privacy-statement/" rel="privacy-policy">Privacy statement</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2631" id="menu-item-2631"><a href="https://www.tiobe.com/report-security-incidents/">Report Security Incidents</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3310" id="menu-item-3310"><a href="https://www.tiobe.com/vulnerability-disclosure-policy/">Vulnerability Disclosure Policy</a></li>
# </ul></div> </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#             _linkedin_partner_id = "440548";
#             window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];
#             window._linkedin_data_partner_ids.push(_linkedin_partner_id);
#         </script>
# <script type="text/javascript">
#             (function(l) {
#                 if (!l){window.lintrk = function(a,b){window.lintrk.q.push([a,b])};
#                 window.lintrk.q=[]}
#                 var s = document.getElementsByTagName("script")[0];
#                 var b = document.createElement("script");
#                 b.type = "text/javascript";b.async = true;
#                 b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#                 s.parentNode.insertBefore(b, s);
#             })(window.lintrk);
#         </script>
# <noscript>
# <img alt="" height="1" src="https://px.ads.linkedin.com/collect/?pid=440548&amp;fmt=gif" style="display:none;" width="1">
# </img></noscript>
# </footer>
# <script type="speculationrules">
# {"prefetch":[{"source":"document","where":{"and":[{"href_matches":"/*"},{"not":{"href_matches":["/wp-*.php","/wp-admin/*","/wp-content/uploads/*","/wp-content/*","/wp-content/plugins/*","/wp-content/themes/tiobe/*","/*\\?(.+)"]}},{"not":{"selector_matches":"a[rel~=\"nofollow\"]"}},{"not":{"selector_matches":".no-prefetch, .no-prefetch a"}}]},"eagerness":"conservative"}]}
# </script>
# <script id="wp-hooks-js" src="https://www.tiobe.com/wp-includes/js/dist/hooks.min.js?ver=dd5603f07f9220ed27f1"></script>
# <script id="wp-i18n-js" src="https://www.tiobe.com/wp-includes/js/dist/i18n.min.js?ver=c26c3dc7bed366793375"></script>
# <script id="wp-i18n-js-after">
# wp.i18n.setLocaleData( { 'text direction\u0004ltr': [ 'ltr' ] } );
# //# sourceURL=wp-i18n-js-after
# </script>
# <script id="swv-js" src="https://www.tiobe.com/wp-content/plugins/contact-form-7/includes/swv/js/index.js?ver=6.1.5"></script>
# <script id="contact-form-7-js-before">
# var wpcf7 = {
#     "api": {
#         "root": "https:\/\/www.tiobe.com\/wp-json\/",
#         "namespace": "contact-form-7\/v1"
#     }
# };
# //# sourceURL=contact-form-7-js-before
# </script>
# <script id="contact-form-7-js" src="https://www.tiobe.com/wp-content/plugins/contact-form-7/includes/js/index.js?ver=6.1.5"></script>
# <script id="jQuery-plugins-js" src="https://www.tiobe.com/wp-content/themes/tiobe/js/plugins.min.js?ver=1.0.0"></script>
# <script id="Main-javascript-file-js" src="https://www.tiobe.com/wp-content/themes/tiobe/js/main.js?ver=1.0.6"></script>
# <script id="google-recaptcha-js" src="https://www.google.com/recaptcha/api.js?render=6LeRk_MlAAAAAJWqnChW2Qrgcv9O6cVZTlpWFPjH&amp;ver=3.0"></script>
# <script id="wp-polyfill-js" src="https://www.tiobe.com/wp-includes/js/dist/vendor/wp-polyfill.min.js?ver=3.15.0"></script>
# <script id="wpcf7-recaptcha-js-before">
# var wpcf7_recaptcha = {
#     "sitekey": "6LeRk_MlAAAAAJWqnChW2Qrgcv9O6cVZTlpWFPjH",
#     "actions": {
#         "homepage": "homepage",
#         "contactform": "contactform"
#     }
# };
# //# sourceURL=wpcf7-recaptcha-js-before
# </script>
# <script id="wpcf7-recaptcha-js" src="https://www.tiobe.com/wp-content/plugins/contact-form-7/modules/recaptcha/index.js?ver=6.1.5"></script>
# </body>
# <script type="speculationrules">
# {"prefetch":[{"source":"document","where":{"and":[{"href_matches":"/*"},{"not":{"href_matches":["/wp-*.php","/wp-admin/*","/wp-content/uploads/*","/wp-content/*","/wp-content/plugins/*","/wp-content/themes/tiobe/*","/*\\?(.+)"]}},{"not":{"selector_matches":"a[rel~=\"nofollow\"]"}},{"not":{"selector_matches":".no-prefetch, .no-prefetch a"}}]},"eagerness":"conservative"}]}
# </script>
#
# </html>

# %%
tables = soup.find_all('table')

# %%
type(tables)
# Out:
# bs4.element.ResultSet

# %%
len(tables)
# Out:
# 4

# %%
# Buscar la tabla específica basada en el caption
# Utilizamos soup.find_all para encontrar todas las tablas (<table>)
#  que tienen la clase 'table-top20' en el documento HTML
# filtrando por la clase se reduce el numero de coincidencias
tables = soup.find_all('table', {'class': 'table-top20'})

print(f"Hemos encontrado {len(tables)} tablas que tienen en la clase 'table-top20' en nuestro documento HTML ")

print(f"\nSi no filtráramos por la clase, encontraríamos {len(soup.find_all('table'))} tablas en nuestro documento HTML ")
# Out:
# Hemos encontrado 1 tablas que tienen en la clase 'table-top20' en nuestro documento HTML
#
# Si no filtráramos por la clase, encontraríamos 4 tablas en nuestro documento HTML

# %%
import pandas as pd

df_p = pd.read_html(str(tables[0]))[0]
df_p
# Out:
# /tmp/ipykernel_2266/151933729.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_p = pd.read_html(str(tables[0]))[0]
#     May 2026  May 2025  Change  Programming Language Programming Language.1  \
# 0          1         1     NaN                   NaN                 Python
# 1          2         3     NaN                   NaN                      C
# 2          3         4     NaN                   NaN                   Java
# 3          4         2     NaN                   NaN                    C++
# 4          5         5     NaN                   NaN                     C#
# 5          6         6     NaN                   NaN             JavaScript
# 6          7         8     NaN                   NaN           Visual Basic
# 7          8        12     NaN                   NaN                      R
# 8          9        10     NaN                   NaN                    SQL
# 9         10         9     NaN                   NaN   Delphi/Object Pascal
# 10        11        11     NaN                   NaN                Fortran
# 11        12        14     NaN                   NaN                Scratch
# 12        13        16     NaN                   NaN                   Perl
# 13        14        15     NaN                   NaN                    PHP
# 14        15        19     NaN                   NaN                   Rust
# 15        16         7     NaN                   NaN                     Go
# 16        17        18     NaN                   NaN      Assembly language
# 17        18        23     NaN                   NaN                  Swift
# 18        19        13     NaN                   NaN                    Ada
# 19        20        17     NaN                   NaN                 MATLAB
#
#    Ratings Change.1
# 0   19.98%   -5.37%
# 1   11.55%   +1.84%
# 2    7.94%   -1.37%
# 3    7.92%   -2.02%
# 4    5.41%   +1.19%
# 5    3.08%   -0.60%
# 6    2.90%   +0.28%
# 7    1.77%   +0.31%
# 8    1.57%   -0.33%
# 9    1.44%   -0.85%
# 10   1.22%   -0.55%
# 11   1.18%   -0.16%
# 12   1.18%   -0.02%
# 13   1.15%   -0.07%
# 14   1.14%   +0.21%
# 15   1.12%   -1.58%
# 16   1.02%   +0.05%
# 17   0.93%   +0.16%
# 18   0.92%   -0.50%
# 19   0.89%   -0.13%

# %%
df_p.head()
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   May 2026                20 non-null     int64
#  1   May 2025                20 non-null     int64
#  2   Change                  0 non-null      float64
#  3   Programming Language    0 non-null      float64
#  4   Programming Language.1  20 non-null     object
#  5   Ratings                 20 non-null     object
#  6   Change.1                20 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.2+ KB

# %%
df_p.columns
# Out:
# Index(['May 2026', 'May 2025', 'Change', 'Programming Language',
#        'Programming Language.1', 'Ratings', 'Change.1'],
#       dtype='object')

# %%
df_p = df_p.drop(columns=['Programming Language', 'Change'])
df_p
# Out:
#     May 2026  May 2025 Programming Language.1 Ratings Change.1
# 0          1         1                 Python  19.98%   -5.37%
# 1          2         3                      C  11.55%   +1.84%
# 2          3         4                   Java   7.94%   -1.37%
# 3          4         2                    C++   7.92%   -2.02%
# 4          5         5                     C#   5.41%   +1.19%
# 5          6         6             JavaScript   3.08%   -0.60%
# 6          7         8           Visual Basic   2.90%   +0.28%
# 7          8        12                      R   1.77%   +0.31%
# 8          9        10                    SQL   1.57%   -0.33%
# 9         10         9   Delphi/Object Pascal   1.44%   -0.85%
# 10        11        11                Fortran   1.22%   -0.55%
# 11        12        14                Scratch   1.18%   -0.16%
# 12        13        16                   Perl   1.18%   -0.02%
# 13        14        15                    PHP   1.15%   -0.07%
# 14        15        19                   Rust   1.14%   +0.21%
# 15        16         7                     Go   1.12%   -1.58%
# 16        17        18      Assembly language   1.02%   +0.05%
# 17        18        23                  Swift   0.93%   +0.16%
# 18        19        13                    Ada   0.92%   -0.50%
# 19        20        17                 MATLAB   0.89%   -0.13%

# %%
df_p = df_p.rename(columns={
    'Programming Language.1​': 'lenguaje',
    'Ratings': 'porcentaje_uso'
})

# %%
df_p
# Out:
#     May 2026  May 2025 Programming Language.1 porcentaje_uso Change.1
# 0          1         1                 Python         19.98%   -5.37%
# 1          2         3                      C         11.55%   +1.84%
# 2          3         4                   Java          7.94%   -1.37%
# 3          4         2                    C++          7.92%   -2.02%
# 4          5         5                     C#          5.41%   +1.19%
# 5          6         6             JavaScript          3.08%   -0.60%
# 6          7         8           Visual Basic          2.90%   +0.28%
# 7          8        12                      R          1.77%   +0.31%
# 8          9        10                    SQL          1.57%   -0.33%
# 9         10         9   Delphi/Object Pascal          1.44%   -0.85%
# 10        11        11                Fortran          1.22%   -0.55%
# 11        12        14                Scratch          1.18%   -0.16%
# 12        13        16                   Perl          1.18%   -0.02%
# 13        14        15                    PHP          1.15%   -0.07%
# 14        15        19                   Rust          1.14%   +0.21%
# 15        16         7                     Go          1.12%   -1.58%
# 16        17        18      Assembly language          1.02%   +0.05%
# 17        18        23                  Swift          0.93%   +0.16%
# 18        19        13                    Ada          0.92%   -0.50%
# 19        20        17                 MATLAB          0.89%   -0.13%

# %%
print(df_p.columns.tolist())
# Out:
# ['May 2026', 'May 2025', 'Programming Language.1', 'porcentaje_uso', 'Change.1']

# %%
df_p.columns = (
    df_p.columns
    .str.strip()
    .str.replace('\u200b','')
)

# %%
df_p = df_p.rename(columns={
    'Programming Language.1​': 'lenguaje'
})

# %%
df_p
# Out:
#     May 2026  May 2025 Programming Language.1 porcentaje_uso Change.1
# 0          1         1                 Python         19.98%   -5.37%
# 1          2         3                      C         11.55%   +1.84%
# 2          3         4                   Java          7.94%   -1.37%
# 3          4         2                    C++          7.92%   -2.02%
# 4          5         5                     C#          5.41%   +1.19%
# 5          6         6             JavaScript          3.08%   -0.60%
# 6          7         8           Visual Basic          2.90%   +0.28%
# 7          8        12                      R          1.77%   +0.31%
# 8          9        10                    SQL          1.57%   -0.33%
# 9         10         9   Delphi/Object Pascal          1.44%   -0.85%
# 10        11        11                Fortran          1.22%   -0.55%
# 11        12        14                Scratch          1.18%   -0.16%
# 12        13        16                   Perl          1.18%   -0.02%
# 13        14        15                    PHP          1.15%   -0.07%
# 14        15        19                   Rust          1.14%   +0.21%
# 15        16         7                     Go          1.12%   -1.58%
# 16        17        18      Assembly language          1.02%   +0.05%
# 17        18        23                  Swift          0.93%   +0.16%
# 18        19        13                    Ada          0.92%   -0.50%
# 19        20        17                 MATLAB          0.89%   -0.13%

# %%
col_old = [c for c in df_p.columns if 'Programming Language' in c][0]
df_p = df_p.rename(columns={col_old: 'lenguaje'})

# %%
df_p
# Out:
#     May 2026  May 2025              lenguaje porcentaje_uso Change.1
# 0          1         1                Python         19.98%   -5.37%
# 1          2         3                     C         11.55%   +1.84%
# 2          3         4                  Java          7.94%   -1.37%
# 3          4         2                   C++          7.92%   -2.02%
# 4          5         5                    C#          5.41%   +1.19%
# 5          6         6            JavaScript          3.08%   -0.60%
# 6          7         8          Visual Basic          2.90%   +0.28%
# 7          8        12                     R          1.77%   +0.31%
# 8          9        10                   SQL          1.57%   -0.33%
# 9         10         9  Delphi/Object Pascal          1.44%   -0.85%
# 10        11        11               Fortran          1.22%   -0.55%
# 11        12        14               Scratch          1.18%   -0.16%
# 12        13        16                  Perl          1.18%   -0.02%
# 13        14        15                   PHP          1.15%   -0.07%
# 14        15        19                  Rust          1.14%   +0.21%
# 15        16         7                    Go          1.12%   -1.58%
# 16        17        18     Assembly language          1.02%   +0.05%
# 17        18        23                 Swift          0.93%   +0.16%
# 18        19        13                   Ada          0.92%   -0.50%
# 19        20        17                MATLAB          0.89%   -0.13%

# %%
#Eliminamos las columnas para obtener df final

df_p = df_p.drop(columns=['May 2026', 'May 2025', 'Change.1'])
df_p
# Out:
#                 lenguaje porcentaje_uso
# 0                 Python         19.98%
# 1                      C         11.55%
# 2                   Java          7.94%
# 3                    C++          7.92%
# 4                     C#          5.41%
# 5             JavaScript          3.08%
# 6           Visual Basic          2.90%
# 7                      R          1.77%
# 8                    SQL          1.57%
# 9   Delphi/Object Pascal          1.44%
# 10               Fortran          1.22%
# 11               Scratch          1.18%
# 12                  Perl          1.18%
# 13                   PHP          1.15%
# 14                  Rust          1.14%
# 15                    Go          1.12%
# 16     Assembly language          1.02%
# 17                 Swift          0.93%
# 18                   Ada          0.92%
# 19                MATLAB          0.89%
